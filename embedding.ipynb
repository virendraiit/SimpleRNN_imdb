# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
## Sentences
sent=[
    'the glass of milk',
    'the glass of juice',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good',
]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
## One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[8958, 9540, 815, 4320],
#  [8958, 9540, 815, 8482],
#  [3995, 3609, 9420, 7777, 9279],
#  [3995, 3609, 9420, 7777, 1718],
#  [2244, 8958, 7012, 815, 6399],
#  [8239, 3851, 7268, 7777]]

# %%
## Word embedding Representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

import numpy as np

# %%
set_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=set_length) # make fixed length for all sentence
print(embedded_docs)
# Out:
# [[   0    0    0    0 8958 9540  815 4320]
#  [   0    0    0    0 8958 9540  815 8482]
#  [   0    0    0 3995 3609 9420 7777 9279]
#  [   0    0    0 3995 3609 9420 7777 1718]
#  [   0    0    0 2244 8958 7012  815 6399]
#  [   0    0    0    0 8239 3851 7268 7777]]

# %%
## Feature Representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=set_length))
model.compile
# Out:
# WARNING:tensorflow:From f:\ML_project\udemy_ml_course\dl_projects\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# <bound method Model.compile of <keras.src.engine.sequential.Sequential object at 0x00000207C012B390>>

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 227ms/step
# array([[[ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.02345926,  0.00859783, -0.0169548 , -0.03837862,
#           0.03637466, -0.01334525,  0.03398303, -0.04616157,
#           0.0006861 ,  0.04068882],
#         [-0.03610364,  0.03869301, -0.01199558, -0.04236096,
#           0.03095943,  0.04338178,  0.00731794,  0.04970368,
#           0.04807111,  0.03141001],
#         [ 0.00914156,  0.02597893,  0.04330435, -0.03033677,
#           0.04206041, -0.04510548, -0.01956987, -0.01478111,
#          -0.01191099, -0.0295221 ],
#         [ 0.04481443, -0.04782729, -0.0417995 , -0.01081133,
#           0.01717783, -0.0351437 , -0.04805062, -0.01416907,
#          -0.03500581,  0.02620568]],
#
#        [[ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.02345926,  0.00859783, -0.0169548 , -0.03837862,
#           0.03637466, -0.01334525,  0.03398303, -0.04616157,
#           0.0006861 ,  0.04068882],
#         [-0.03610364,  0.03869301, -0.01199558, -0.04236096,
#           0.03095943,  0.04338178,  0.00731794,  0.04970368,
#           0.04807111,  0.03141001],
#         [ 0.00914156,  0.02597893,  0.04330435, -0.03033677,
#           0.04206041, -0.04510548, -0.01956987, -0.01478111,
#          -0.01191099, -0.0295221 ],
#         [ 0.03520444,  0.04755408,  0.03005426, -0.0062794 ,
#           0.0499103 , -0.04276705,  0.02415724,  0.02100484,
#          -0.00200968, -0.0305765 ]],
#
#        [[ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [-0.04328271, -0.01105358,  0.00779406, -0.03942953,
#          -0.04158261,  0.00463756, -0.00165241,  0.03216619,
#           0.04981451,  0.03921122],
#         [-0.02598411,  0.01703637,  0.03984407, -0.01466682,
#          -0.04541298,  0.00197272,  0.04322207,  0.03572191,
#          -0.02927974,  0.03346727],
#         [-0.03934901, -0.0015889 ,  0.02968231,  0.00961115,
#           0.04800346, -0.01603359,  0.03485974, -0.04529792,
#          -0.03882061, -0.03077127],
#         [ 0.04159174,  0.03615573, -0.02111541, -0.00673704,
#           0.02917378,  0.00334523,  0.03519595, -0.04549282,
#           0.03990147,  0.0176744 ],
#         [-0.01566698, -0.00176222,  0.00801233,  0.02496466,
#          -0.00302263,  0.04822625,  0.00240735,  0.00657884,
#           0.04446859, -0.00433622]],
#
#        [[ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [-0.04328271, -0.01105358,  0.00779406, -0.03942953,
#          -0.04158261,  0.00463756, -0.00165241,  0.03216619,
#           0.04981451,  0.03921122],
#         [-0.02598411,  0.01703637,  0.03984407, -0.01466682,
#          -0.04541298,  0.00197272,  0.04322207,  0.03572191,
#          -0.02927974,  0.03346727],
#         [-0.03934901, -0.0015889 ,  0.02968231,  0.00961115,
#           0.04800346, -0.01603359,  0.03485974, -0.04529792,
#          -0.03882061, -0.03077127],
#         [ 0.04159174,  0.03615573, -0.02111541, -0.00673704,
#           0.02917378,  0.00334523,  0.03519595, -0.04549282,
#           0.03990147,  0.0176744 ],
#         [ 0.03600664,  0.00438945, -0.00311258, -0.03313701,
#           0.01066115,  0.02453085, -0.03808914,  0.02177988,
#          -0.02976979, -0.00053031]],
#
#        [[ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.02783482, -0.0467898 , -0.02627634, -0.03162521,
#           0.02756235,  0.02295431, -0.02320881,  0.00982793,
#           0.01424279,  0.04244525],
#         [ 0.02345926,  0.00859783, -0.0169548 , -0.03837862,
#           0.03637466, -0.01334525,  0.03398303, -0.04616157,
#           0.0006861 ,  0.04068882],
#         [-0.03231468, -0.02901578,  0.0247265 ,  0.0151738 ,
#          -0.02880874, -0.02260685,  0.01430626,  0.04194242,
#          -0.01495217,  0.00687951],
#         [ 0.00914156,  0.02597893,  0.04330435, -0.03033677,
#           0.04206041, -0.04510548, -0.01956987, -0.01478111,
#          -0.01191099, -0.0295221 ],
#         [-0.01526257,  0.02075933,  0.02422634, -0.03885514,
#           0.04345645, -0.04713029, -0.01290631, -0.02626876,
#           0.02961068,  0.04805347]],
#
#        [[ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,
#           0.01406259,  0.01923944, -0.02462581,  0.04726274,
#          -0.02681809, -0.01226516],
#         [-0.03102765, -0.02003013, -0.0188482 , -0.04206054,
#           0.03044245,  0.02074759, -0.02670943, -0.02813175,
#           0.0441831 ,  0.01197513],
#         [-0.0359045 , -0.03707752, -0.0138244 , -0.04639322,
#          -0.01651405, -0.02635053,  0.01757411,  0.00489091,
#           0.04272511, -0.0487908 ],
#         [ 0.04909681,  0.00132149, -0.02270235,  0.03866054,
#          -0.03989003,  0.04300748,  0.03168659, -0.04613184,
#          -0.01443598, -0.02012323],
#         [ 0.04159174,  0.03615573, -0.02111541, -0.00673704,
#           0.02917378,  0.00334523,  0.03519595, -0.04549282,
#           0.03990147,  0.0176744 ]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 8958, 9540,  815, 4320])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 179ms/step
# array([[ 0.00501119,  0.02844529,  0.00740749,  0.01358647,  0.01406259,
#          0.01923944, -0.02462581,  0.04726274, -0.02681809, -0.01226516],
#        [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,  0.01406259,
#          0.01923944, -0.02462581,  0.04726274, -0.02681809, -0.01226516],
#        [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,  0.01406259,
#          0.01923944, -0.02462581,  0.04726274, -0.02681809, -0.01226516],
#        [ 0.00501119,  0.02844529,  0.00740749,  0.01358647,  0.01406259,
#          0.01923944, -0.02462581,  0.04726274, -0.02681809, -0.01226516],
#        [ 0.02345926,  0.00859783, -0.0169548 , -0.03837862,  0.03637466,
#         -0.01334525,  0.03398303, -0.04616157,  0.0006861 ,  0.04068882],
#        [-0.03610364,  0.03869301, -0.01199558, -0.04236096,  0.03095943,
#          0.04338178,  0.00731794,  0.04970368,  0.04807111,  0.03141001],
#        [ 0.00914156,  0.02597893,  0.04330435, -0.03033677,  0.04206041,
#         -0.04510548, -0.01956987, -0.01478111, -0.01191099, -0.0295221 ],
#        [ 0.04481443, -0.04782729, -0.0417995 , -0.01081133,  0.01717783,
#         -0.0351437 , -0.04805062, -0.01416907, -0.03500581,  0.02620568]],
#       dtype=float32)
